# %%
# magic functions
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# import libraries
from fastai.vision import *
from fastai.metrics import error_rate

# %%
# create a dictionary of folders and url files
folder_dict = {
    'mtp':'mtp.txt',
    'gd':'gd.txt',
}

# %%
# create folders
for folder in folder_dict.keys():
    path = Path('data/')
    dest = path/folder
    dest.mkdir(parents=True, exist_ok=True)

# %%
# download images into folders
for folder, file in folder_dict.items():
    path = Path('data/')
    dest = path/folder
    download_images(path/file, dest, max_pics=100)

# %%
# verify and delete if a downloaded image is not in valid format
classes = list(folder_dict.keys())

for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# mtp
# gd

# %%
# create a DataBunch
np.random.seed(13)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, bs=16, num_workers=4).normalize(imagenet_stats)

# %%
len(data.train_ds), len(data.valid_ds)
# Out:
# (152, 37)

# %%
# have a look at some random images
data.show_batch(rows=3, figsize=(7,8))

# %%
# create a model using pre-trained resnet34
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# train the model with 4 epoches
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.755998</td>
#       <td>1.071209</td>
#       <td>0.594595</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.407860</td>
#       <td>1.473269</td>
#       <td>0.567568</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.332619</td>
#       <td>1.417654</td>
#       <td>0.567568</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.085022</td>
#       <td>1.389546</td>
#       <td>0.648649</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1') # save the weights

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,11)) # plot with prediction/actual/loss/probability

# %%
np.random.seed(13)
cleaned_data = ImageDataBunch.from_csv(path, valid_pct=0.2, csv_labels="cleaned.csv",
        ds_tfms=get_transforms(), size=224, bs=16, num_workers=4).normalize(imagenet_stats)

cleaned_data.show_batch(rows=3, figsize=(7,8)) # have a look at images

# %%
learn_cln = cnn_learner(cleaned_data, models.resnet34, metrics=accuracy)

# %%
learn_cln.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.101103</td>
#       <td>0.705790</td>
#       <td>0.666667</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.033963</td>
#       <td>0.836205</td>
#       <td>0.694444</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.905114</td>
#       <td>0.600048</td>
#       <td>0.805556</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.781122</td>
#       <td>0.474901</td>
#       <td>0.805556</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_cln.save('stage-2')

# %%
learn_cln.export()

# %%
new_learn = load_learner(path)
img = open_image(path/'test'/'1.jpg')
img
# Out:
# Image (3, 500, 500)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-1');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
np.random.seed(13)
cleaned_data = ImageDataBunch.from_csv(path, valid_pct=0.2, csv_labels="cleaned.csv",
        ds_tfms=get_transforms(), size=224, bs=16, num_workers=4).normalize(imagenet_stats)

cleaned_data.show_batch(rows=3, figsize=(7,8)) # have a look at images

# %%
len(cleaned_data.train_ds), len(cleaned_data.valid_ds)

# %%
learn_cln = cnn_learner(cleaned_data, models.resnet34, metrics=accuracy)
learn_cln.load('stage-1');

# %%
learn_cln.fit_one_cycle(4)

# %%
learn_cln.save('stage-2')

# %%
learn_cln.unfreeze()

# %%
learn_cln.lr_find()
learn_cln.recorder.plot(suggestion = True)

# %%
learn_cln.fit_one_cycle(4, max_lr=slice(7e-05,3e-04))

# %%
learn_cln.save('stage-3')

# %%
learn_cln.load('stage-2');

# %%
learn_cln.export()

# %%
learn = load_learner(path)

# %%
data.predict()
